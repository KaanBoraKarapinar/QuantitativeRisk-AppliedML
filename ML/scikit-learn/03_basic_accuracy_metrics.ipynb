# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# # Confusion Matrix
# ![image.png](attachment:6bfacbe5-9ae4-4f29-a1f6-40d5315788c4.png)

# %% [markdown]
# ## Precision
# ![image.png](attachment:09861b70-75a3-4a4a-88c1-acffbfb3fed8.png)
# ![image.png](attachment:2ab7e4d3-3ea8-4d3c-b546-a915411f7447.png)
# ## Recall (Sensitivity)
# ![image.png](attachment:c2f7e11a-fac7-4557-aec6-54f3955d6233.png)
# ![image.png](attachment:37bc550d-1a2f-4f21-b047-a3fcb9f9e2e6.png)
# ## F1 Score
# ![image.png](attachment:7bde19d4-4e48-487a-a292-06432fcabe9b.png)

# %% [markdown]
# ## Roc Curve
# ![image.png](attachment:34ec8cd8-3210-428d-81da-86795b1555b5.png)
# p being the probability treshold of logictic regression
# at p=- whave just
