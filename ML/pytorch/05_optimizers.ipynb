# %% [markdown]
# ## Stochaistic Gradient Descent + (Effect of Learning Rate and Momentum)
#
# Pytorch : `sgd = optim.SGD(model.parameters(), lr=0.01, momentum=0.95)`
#
# learning rate: controls the step size
# momentum: adds inertia to avoid getting stuck
#
#
# ### Optimal Learning Rate
# #### optimal
# ![image.png](attachment:fb02f32a-edb4-4966-b61b-bcc6ad342b3d.png)
# #### small
# ![image.png](attachment:1e639ada-8408-4737-92c8-5d4bba4e1684.png)
# #### high
# ![image.png](attachment:57b5a02c-bba2-4a34-924e-6366a3d716c4.png)
#
#
# ### Optimal Momentum
#
# typical range: 0.85-0.99
#
# Its used to handle the unconvexity and escape from the local minima:
# ![image.png](attachment:6cecc496-7f15-4c1f-870a-9c09dd810b26.png)
# ![image.png](attachment:7ec5580a-2a52-4ac2-8bb0-437ab3110316.png)
